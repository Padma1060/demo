# %% [markdown]
# <a href="https://colab.research.google.com/github/Padma1060/demo/blob/master/spark.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pyspark

# %%
from pyspark.sql import SparkSession

# %%
#start the spark session
spark=SparkSession.builder.appName('DataFrame').getOrCreate()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://53d38a341f5f:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.3</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>DataFrame</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
df=spark.read.option('header','true').csv('/content/test1.csv',inferSchema=True)
# if we wnt exact data type we will use inferschema

# %%
df.printSchema() # check the schema
# Out:
# root
#  |-- Name: string (nullable = true)
#  |-- age: integer (nullable = true)
#  |-- Experience: integer (nullable = true)
#  |-- Salary: integer (nullable = true)

# %%
type(df)
# Out:
# pyspark.sql.classic.dataframe.DataFrame

# %%
df=spark.read.csv('/content/test1.csv',header=True,inferSchema=True)
df.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
#selecting single column
df.select('Name').show()
# Out:
# +--------+
# |    Name|
# +--------+
# |     Ben|
# |Srikanth|
# |   Sunny|
# |    Paul|
# |  Harish|
# |   Shiva|
# +--------+

# %%
#select multiple columns
df.select('Name','age').show()
# Out:
# +--------+---+
# |    Name|age|
# +--------+---+
# |     Ben| 31|
# |Srikanth| 30|
# |   Sunny| 29|
# |    Paul| 24|
# |  Harish| 21|
# |   Shiva| 23|
# +--------+---+

# %%
df.select(['Name','age','Experience']).show()
# Out:
# +--------+---+----------+
# |    Name|age|Experience|
# +--------+---+----------+
# |     Ben| 31|        10|
# |Srikanth| 30|         8|
# |   Sunny| 29|         4|
# |    Paul| 24|         3|
# |  Harish| 21|         1|
# |   Shiva| 23|         2|
# +--------+---+----------+

# %%
df.filter(df['Name']=='Ben').show()
# Out:
# +----+---+----------+------+
# |Name|age|Experience|Salary|
# +----+---+----------+------+
# | Ben| 31|        10| 30000|
# +----+---+----------+------+

# %%
df.dtypes
# Out:
# [('Name', 'string'), ('age', 'int'), ('Experience', 'int'), ('Salary', 'int')]

# %%
df.describe().show()
# Out:
# +-------+-----+------------------+-----------------+------------------+
# |summary| Name|               age|       Experience|            Salary|
# +-------+-----+------------------+-----------------+------------------+
# |  count|    6|                 6|                6|                 6|
# |   mean| NULL|26.333333333333332|4.666666666666667|21333.333333333332|
# | stddev| NULL| 4.179314138308661|3.559026084010437| 5354.126134736337|
# |    min|  Ben|                21|                1|             15000|
# |    max|Sunny|                31|               10|             30000|
# +-------+-----+------------------+-----------------+------------------+

# %%
ord('B')
# Out:
# 66

# %%
ord('r')
ord('P')
ord('u')
# Out:
# 80

# %%
df=df.withColumn('Experience After 2 year',df['Experience']+2)# it used to add the column
df.show()
# Out:
# +--------+---+----------+------+-----------------------+
# |    Name|age|Experience|Salary|Experience After 2 year|
# +--------+---+----------+------+-----------------------+
# |     Ben| 31|        10| 30000|                     12|
# |Srikanth| 30|         8| 25000|                     10|
# |   Sunny| 29|         4| 20000|                      6|
# |    Paul| 24|         3| 20000|                      5|
# |  Harish| 21|         1| 15000|                      3|
# |   Shiva| 23|         2| 18000|                      4|
# +--------+---+----------+------+-----------------------+

# %%
df=df.drop('Experience After 2 year')

# %%
df.show()
# Out:
# +--------+---+----------+------+
# |    Name|age|Experience|Salary|
# +--------+---+----------+------+
# |     Ben| 31|        10| 30000|
# |Srikanth| 30|         8| 25000|
# |   Sunny| 29|         4| 20000|
# |    Paul| 24|         3| 20000|
# |  Harish| 21|         1| 15000|
# |   Shiva| 23|         2| 18000|
# +--------+---+----------+------+

# %%
df.withColumnRenamed('Name','New_Name').show()
# Out:
# +--------+---+----------+------+-----------------------+
# |New_Name|age|Experience|Salary|Experience After 2 year|
# +--------+---+----------+------+-----------------------+
# |     Ben| 31|        10| 30000|                     12|
# |Srikanth| 30|         8| 25000|                     10|
# |   Sunny| 29|         4| 20000|                      6|
# |    Paul| 24|         3| 20000|                      5|
# |  Harish| 21|         1| 15000|                      3|
# |   Shiva| 23|         2| 18000|                      4|
# +--------+---+----------+------+-----------------------+
